# %% [markdown]
# ## BPE 分词器，GPT-2、GPT-3 和 ChatGPT的原始模型

# %% [markdown]
# 由于BPE的实现相对复杂，因此我们将使用现有的Python开源库 tiktoken，它基于Rust的源代码实现的BPE算法。
#
# 通过python的pip安装器从终端安装tiktoken库

# %% [markdown]
# $ pip install tiktoken

# %%
from importlib.metadata import version
import tiktoken
print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
import token


tokenizer = tiktoken.get_encoding("gpt2")

text = (
    "Hello, do you  like tea? <|endoftext|> In the sunlit terraces"
    "of somunknowPlace."
)
integers = tokenizer.encode(text,allowed_special={"<|endoftext|>"})
print(integers)
# Out:
# [15496, 11, 466, 345, 220, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 3870, 2954, 2197, 27271, 13]

# %%
strings = tokenizer.decode(integers)
print(strings)
# Out:
# Hello, do you  like tea? <|endoftext|> In the sunlit terracesof somunknowPlace.

# %%
integers = tokenizer.encode("Akwirw ier")
print(integers)
# Out:
# [33901, 86, 343, 86, 220, 959]

# %%
print(tokenizer.decode(integers))
# Out:
# Akwirw ier

# %% [markdown]
# 2. 使用滑动窗口进行数据采样
#
# 使用BPE分词器对文本进行全文分词：

# %%
with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(f"Length of text: {len(enc_text)} tokens")
# Out:
# Length of text: 5145 tokens

# %% [markdown]
# 上述代码执行返回5145，这是应用BPE分词器后的训练集中词元总数。
